# %% [markdown]
# # Learning Outcome
#
# 1. To understand the installation process of Anaconda and a few Python libraries for performing data pre-processing
# 2. To get acquainted with the functionalities of Pandas in data analysis
# 3. To learn various tools and techniques for compensating missing values in the given data
# 4. To understand the various ways of data standardisation and normalisation
# 5. To learn the basic visualisation techniques in Python

# %% [markdown]
# ## Task 1
#
# Import the dataset World GDP.csv and store as a Pandas data frame. As demonstrated during the
# workshop, perform some basics operations on this data frame such as, reading data, making changes
# in the data frame, saving data into desired format, filtering and aggregate statistics.

# %%
# loading libraries

import pandas as pd
import numpy as np

# %%
# loading the data
# i know its bad practise but couldbe bothered to change the slashes lol

world_gdp_data = pd.read_csv(r"C:\Users\44783\Downloads\World GDP.csv")

world_gdp_data.head()
# Out:
#   Country Name Country Code           Indicator Name  Indicator Code  1960  \
# 0        Aruba          ABW  GDP (constant 2010 US$)  NY.GDP.MKTP.KD   NaN
# 1  Afghanistan          AFG  GDP (constant 2010 US$)  NY.GDP.MKTP.KD   NaN
# 2       Angola          AGO  GDP (constant 2010 US$)  NY.GDP.MKTP.KD   NaN
# 3      Albania          ALB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD   NaN
# 4      Andorra          AND  GDP (constant 2010 US$)  NY.GDP.MKTP.KD   NaN
#
#    1961  1962  1963  1964  1965  ...          2010          2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  2.390503e+09  2.472881e+09
# 1   NaN   NaN   NaN   NaN   NaN  ...  1.585657e+10  1.592418e+10
# 2   NaN   NaN   NaN   NaN   NaN  ...  8.379950e+10  8.670900e+10
# 3   NaN   NaN   NaN   NaN   NaN  ...  1.192693e+10  1.223051e+10
# 4   NaN   NaN   NaN   NaN   NaN  ...  3.449967e+09  3.449688e+09
#
#            2012          2013          2014          2015          2016  \
# ...

# %% [markdown]
# # # TASK 2
# Choose any five countries of your choice and make a new data frame containing only five countries
# and their GDP data (from 1960 until 2019).

# %%
# to show unique countries

world_gdp_data["Country Name"].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
# ...

# %%
# create a country list

countries = ['South Africa', 'Zambia', 'Zimbabwe', 'Tanzania', 'Malawi']

#filter out the list

africa_gdp = world_gdp_data[world_gdp_data["Country Name"].isin(countries)]

africa_gdp
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#              1960          1961          1962          1963          1964  \
# 166  8.727495e+08  9.394241e+08  9.457029e+08  9.325474e+08  9.573635e+08
# 244           NaN           NaN           NaN           NaN           NaN
# 261  7.907096e+10  8.211104e+10  8.718376e+10  9.361236e+10  1.010450e+11
# 262  4.592976e+09  4.655504e+09  4.539543e+09  4.688094e+09  5.260700e+09
# 263  3.756656e+09  3.993933e+09  4.051225e+09  4.304197e+09  4.256585e+09
#
#              1965  ...          2010          2011          2012  \
# ...

# %%
# old school filter method

#selected_countries = (world_gdp_data["Country Name"] == 'South Africa') | (world_gdp_data["Country Name"] == 'Zambia')|(world_gdp_data["Country Name"] == 'Zimbabwe') | (world_gdp_data["Country Name"] == 'Tanzania')|(world_gdp_data["Country Name"] == 'Malawi')

# %%
#africa_gdp = world_gdp_data[selected_countries]
#africa_gdp
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#              1960          1961          1962          1963          1964  \
# 166  8.727495e+08  9.394241e+08  9.457029e+08  9.325474e+08  9.573635e+08
# 244           NaN           NaN           NaN           NaN           NaN
# 261  7.907096e+10  8.211104e+10  8.718376e+10  9.361236e+10  1.010450e+11
# 262  4.592976e+09  4.655504e+09  4.539543e+09  4.688094e+09  5.260700e+09
# 263  3.756656e+09  3.993933e+09  4.051225e+09  4.304197e+09  4.256585e+09
#
#              1965  ...          2010          2011          2012  \
# ...

# %% [markdown]
# # Task 3
#
# Perform z-score standardisation on the GDP data (1960-2019) of all the five countries.

# %%
africa_gdp_2 = africa_gdp.copy()

africa_gdp_2.dropna(axis=1,inplace=True)
africa_gdp_2.tail(10)
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#              1988          1989          1990          1991          1992  \
# 166  2.912753e+09  2.951921e+09  3.119953e+09  3.392332e+09  3.143573e+09
# 244  1.137711e+10  1.180539e+10  1.263709e+10  1.289893e+10  1.297430e+10
# 261  2.184820e+11  2.237150e+11  2.230040e+11  2.207330e+11  2.160160e+11
# 262  8.515953e+09  8.428792e+09  8.388243e+09  8.385212e+09  8.240071e+09
# 263  1.285471e+10  1.352312e+10  1.446819e+10  1.526854e+10  1.389200e+10
#
#              1993  ...          2011          2012          2013  \
# ...

# %%
#africa_numerical = africa_gdp_2.select_dtypes(exclude = ["object"])

#africa_numerical
# Out:
#              1988          1989          1990          1991          1992  \
# 166  2.912753e+09  2.951921e+09  3.119953e+09  3.392332e+09  3.143573e+09
# 244  1.137711e+10  1.180539e+10  1.263709e+10  1.289893e+10  1.297430e+10
# 261  2.184820e+11  2.237150e+11  2.230040e+11  2.207330e+11  2.160160e+11
# 262  8.515953e+09  8.428792e+09  8.388243e+09  8.385212e+09  8.240071e+09
# 263  1.285471e+10  1.352312e+10  1.446819e+10  1.526854e+10  1.389200e+10
#
#              1993          1994          1995          1996          1997  \
# 166  3.448243e+09  3.095136e+09  3.612916e+09  3.877262e+09  4.024304e+09
# 244  1.313075e+10  1.333659e+10  1.381270e+10  1.444040e+10  1.494946e+10
# 261  2.186800e+11  2.256780e+11  2.326740e+11  2.426790e+11  2.489890e+11
# 262  8.800171e+09  8.041118e+09  8.274122e+09  8.788653e+09  9.123853e+09
# 263  1.403806e+10  1.533451e+10  1.535874e+10  1.695001e+10  1.740437e+10
#
#      ...          2011          2012          2013          2014  \
# ...

# %%
from scipy.stats import zscore

africa_gdp_2["zscore"] = zscore(africa_gdp_2["1988"])
africa_gdp_2["zscore"]
# Out:
# 166   -0.571135
# 244   -0.470244
# 261    1.998358
# 262   -0.504347
# 263   -0.452631
# Name: zscore, dtype: float64

# %%
# create a country list

countries = ['South Africa', 'Zambia', 'Zimbabwe', 'Tanzania', 'Malawi']

#filter out the list

africa_gdp = world_gdp_data[world_gdp_data["Country Name"].isin(countries)]

africa_gdp
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#              1960          1961          1962          1963          1964  \
# 166  8.727495e+08  9.394241e+08  9.457029e+08  9.325474e+08  9.573635e+08
# 244           NaN           NaN           NaN           NaN           NaN
# 261  7.907096e+10  8.211104e+10  8.718376e+10  9.361236e+10  1.010450e+11
# 262  4.592976e+09  4.655504e+09  4.539543e+09  4.688094e+09  5.260700e+09
# 263  3.756656e+09  3.993933e+09  4.051225e+09  4.304197e+09  4.256585e+09
#
#              1965  ...          2010          2011          2012  \
# ...

# %%
#test_data = africa_gdp.melt(id_vars = 'Country Name', var_name = 'Year', value_name = 'test')

#test2 = pd.melt(africa_gdp, id_vars = 'Country Name', var_name = 'Year', value_name = 'test')

#test2.head()
# Out:
#    Country Name          Year test
# 0        Malawi  Country Code  MWI
# 1      Tanzania  Country Code  TZA
# 2  South Africa  Country Code  ZAF
# 3        Zambia  Country Code  ZMB
# 4      Zimbabwe  Country Code  ZWE

# %% [markdown]
# # TASK 4
#
# Performs some normalisation techniques such as, min-max, log scaling on the GDP data (1960-2019)
# of all the five countries.

# %%
africa_gdp_3 = africa_gdp.copy()

# %%
africa_gdp_3["1988"] = africa_gdp_3["1988"]/africa_gdp_3["1988"].max()

africa_gdp_3.head()
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#          1988          1989          1990          1991          1992  \
# 166  0.013332  2.951921e+09  3.119953e+09  3.392332e+09  3.143573e+09
# 244  0.052073  1.180539e+10  1.263709e+10  1.289893e+10  1.297430e+10
# 261  1.000000  2.237150e+11  2.230040e+11  2.207330e+11  2.160160e+11
# 262  0.038978  8.428792e+09  8.388243e+09  8.385212e+09  8.240071e+09
# 263  0.058836  1.352312e+10  1.446819e+10  1.526854e+10  1.389200e+10
#
#              1993  ...          2011          2012          2013  \
# ...

# %%
africa_gdp_3['1989'] = africa_gdp_3['1989'].apply(lambda x: np.log(x) if x != 0 else 0)

africa_gdp_3.head()
# Out:
#      Country Name Country Code           Indicator Name  Indicator Code  \
# 166        Malawi          MWI  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 244      Tanzania          TZA  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 261  South Africa          ZAF  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 262        Zambia          ZMB  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 263      Zimbabwe          ZWE  GDP (constant 2010 US$)  NY.GDP.MKTP.KD
#
#          1988      1989          1990          1991          1992  \
# 166  0.013332  3.082172  3.119953e+09  3.392332e+09  3.143573e+09
# 244  0.052073  3.143800  1.263709e+10  1.289893e+10  1.297430e+10
# 261  1.000000  3.263223  2.230040e+11  2.207330e+11  2.160160e+11
# 262  0.038978  3.129166  8.388243e+09  8.385212e+09  8.240071e+09
# 263  0.058836  3.149640  1.446819e+10  1.526854e+10  1.389200e+10
#
#              1993  ...          2011          2012          2013  \
# 166  3.448243e+09  ...  7.297481e+09  7.435097e+09  7.821722e+09
# ...

# %% [markdown]
# # TASK 5
#
# Visualise the GDP changes of all the chosen five countries from 1960-2019 using line plots and
# scatter plots.

# %%
#for column in df123:
#df123[column]= df123[column].apply(lambda x: np.log(x) if x != 0 else 0)
